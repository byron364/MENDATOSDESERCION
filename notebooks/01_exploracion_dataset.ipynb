# %%
import pandas as pd

df = pd.read_csv(
    "../data set modificado.csv",
    sep=";"
)

df.head()
# Out:
#       AÑO  CÓDIGO_DEPARTAMENTO     DEPARTAMENTO  POBLACIÓN_5_16  \
# 0  2023.0                   76  Valle del Cauca        842813.0
# 1  2012.0                   27            Chocó        145607.0
# 2     NaN                   52           Nariño        394574.0
# 3  2024.0                   63              NaN         82391.0
# 4  2023.0                   25     Cundinamarca        598065.0
#
#   TASA_MATRICULACIÓN_5_16 COBERTURA_NETA COBERTURA_NETA_TRANSICIÓN  \
# 0                  78,09%         77,90%                    58,61%
# 1                  80,97%            NaN                    62,17%
# 2                  71,10%         71,13%                    38,56%
# 3                  90,10%         90,05%                    68,48%
# 4                  93,59%         93,32%                    62,91%
#
#   COBERTURA_NETA_PRIMARIA COBERTURA_NETA_SECUNDARIA COBERTURA_NETA_MEDIA  ...  \
# 0                  74,78%                    66,48%               46,35%  ...
# ...

# %% [markdown]
# inspeccion general del Dataset
# se alaliza
# número de Registros
# Número de variables
# Tipos de datos
# Consistencia de columnas

# %%
#Dimensiones
print(df.shape)
#Infornación General
print(df.info())
#Tipos de datos
print(df.dtypes)
# Out:
# (485, 37)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485 entries, 0 to 484
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   AÑO                          452 non-null    float64
#  1   CÓDIGO_DEPARTAMENTO          485 non-null    int64
#  2   DEPARTAMENTO                 466 non-null    object
#  3   POBLACIÓN_5_16               452 non-null    float64
#  4   TASA_MATRICULACIÓN_5_16      485 non-null    object
#  5   COBERTURA_NETA               456 non-null    object
#  6   COBERTURA_NETA_TRANSICIÓN    456 non-null    object
#  7   COBERTURA_NETA_PRIMARIA      456 non-null    object
#  8   COBERTURA_NETA_SECUNDARIA    485 non-null    object
#  9   COBERTURA_NETA_MEDIA         485 non-null    object
#  10  COBERTURA_BRUTA              456 non-null    object
#  11  COBERTURA_BRUTA_TRANSICIÓN   456 non-null    object
# ...

# %%
print(f"Filas: {df.shape[0]}")
print(f"Columnas: {df.shape[1]}")
# Out:
# Filas: 485
# Columnas: 37

# %%
#Valores nulos 
df.isnull().sum()
# Out:
# AÑO                             33
# CÓDIGO_DEPARTAMENTO              0
# DEPARTAMENTO                    19
# POBLACIÓN_5_16                  33
# TASA_MATRICULACIÓN_5_16          0
# COBERTURA_NETA                  29
# COBERTURA_NETA_TRANSICIÓN       29
# COBERTURA_NETA_PRIMARIA         29
# COBERTURA_NETA_SECUNDARIA        0
# COBERTURA_NETA_MEDIA             0
# COBERTURA_BRUTA                 29
# COBERTURA_BRUTA_TRANSICIÓN      29
# COBERTURA_BRUTA_PRIMARIA        29
# COBERTURA_BRUTA_SECUNDARIA       0
# COBERTURA_BRUTA_MEDIA           36
# TAMAÑO_PROMEDIO_DE_GRUPO       240
# SEDES_CONECTADAS_A_INTERNET    256
# DESERCIÓN                       29
# DESERCIÓN_TRANSICIÓN             1
# DESERCIÓN_PRIMARIA               0
# DESERCIÓN_SECUNDARIA            37
# DESERCIÓN_MEDIA                  0
# APROBACIÓN                       8
# APROBACIÓN_TRANSICIÓN           29
# APROBACIÓN_PRIMARIA              0
# APROBACIÓN_SECUNDARIA            0
# APROBACIÓN_MEDIA                 8
# ...

# %%
#Valores nulos 
df.isnull().sum()
#porcentaje de nulos
(df.isnull().sum() / len(df))*100
# Out:
# AÑO                             6.804124
# CÓDIGO_DEPARTAMENTO             0.000000
# DEPARTAMENTO                    3.917526
# POBLACIÓN_5_16                  6.804124
# TASA_MATRICULACIÓN_5_16         0.000000
# COBERTURA_NETA                  5.979381
# COBERTURA_NETA_TRANSICIÓN       5.979381
# COBERTURA_NETA_PRIMARIA         5.979381
# COBERTURA_NETA_SECUNDARIA       0.000000
# COBERTURA_NETA_MEDIA            0.000000
# COBERTURA_BRUTA                 5.979381
# COBERTURA_BRUTA_TRANSICIÓN      5.979381
# COBERTURA_BRUTA_PRIMARIA        5.979381
# COBERTURA_BRUTA_SECUNDARIA      0.000000
# COBERTURA_BRUTA_MEDIA           7.422680
# TAMAÑO_PROMEDIO_DE_GRUPO       49.484536
# SEDES_CONECTADAS_A_INTERNET    52.783505
# DESERCIÓN                       5.979381
# DESERCIÓN_TRANSICIÓN            0.206186
# DESERCIÓN_PRIMARIA              0.000000
# DESERCIÓN_SECUNDARIA            7.628866
# DESERCIÓN_MEDIA                 0.000000
# APROBACIÓN                      1.649485
# ...

# %%
#Registros duplicados
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.describe()
# Out:
#                AÑO  CÓDIGO_DEPARTAMENTO  POBLACIÓN_5_16  \
# count   452.000000           485.000000    4.520000e+02
# mean   2017.376106            52.204124    2.946784e+05
# std       4.073619            30.493083    3.033231e+05
# min    2011.000000             5.000000    1.072600e+04
# 25%    2014.000000            20.000000    8.678925e+04
# 50%    2017.000000            52.000000    2.341535e+05
# 75%    2021.000000            81.000000    3.339912e+05
# max    2024.000000            99.000000    1.479334e+06
#
#        SEDES_CONECTADAS_A_INTERNET
# count                   229.000000
# mean                     34.575284
# std                      20.994989
# min                       0.000000
# 25%                      20.300000
# 50%                      30.280000
# 75%                      41.620000
# max                      99.860000

# %%
df.describe().T
# Out:
#                              count           mean            std      min  \
# AÑO                          452.0    2017.376106       4.073619   2011.0
# CÓDIGO_DEPARTAMENTO          485.0      52.204124      30.493083      5.0
# POBLACIÓN_5_16               452.0  294678.384956  303323.068466  10726.0
# SEDES_CONECTADAS_A_INTERNET  229.0      34.575284      20.994989      0.0
#
#                                   25%        50%        75%         max
# AÑO                           2014.00    2017.00    2021.00     2024.00
# CÓDIGO_DEPARTAMENTO             20.00      52.00      81.00       99.00
# POBLACIÓN_5_16               86789.25  234153.50  333991.25  1479334.00
# SEDES_CONECTADAS_A_INTERNET     20.30      30.28      41.62       99.86

# %%
#variables categóricas
df.select_dtypes(include='object').columns
# Out:
# Index(['DEPARTAMENTO', 'TASA_MATRICULACIÓN_5_16', 'COBERTURA_NETA',
#        'COBERTURA_NETA_TRANSICIÓN', 'COBERTURA_NETA_PRIMARIA',
#        'COBERTURA_NETA_SECUNDARIA', 'COBERTURA_NETA_MEDIA', 'COBERTURA_BRUTA',
#        'COBERTURA_BRUTA_TRANSICIÓN', 'COBERTURA_BRUTA_PRIMARIA',
#        'COBERTURA_BRUTA_SECUNDARIA', 'COBERTURA_BRUTA_MEDIA',
#        'TAMAÑO_PROMEDIO_DE_GRUPO', 'DESERCIÓN', 'DESERCIÓN_TRANSICIÓN',
#        'DESERCIÓN_PRIMARIA', 'DESERCIÓN_SECUNDARIA', 'DESERCIÓN_MEDIA',
#        'APROBACIÓN', 'APROBACIÓN_TRANSICIÓN', 'APROBACIÓN_PRIMARIA',
#        'APROBACIÓN_SECUNDARIA', 'APROBACIÓN_MEDIA', 'REPROBACIÓN',
#        'REPROBACIÓN_TRANSICIÓN', 'REPROBACIÓN_PRIMARIA',
#        'REPROBACIÓN_SECUNDARIA', 'REPROBACIÓN_MEDIA', 'REPITENCIA',
#        'REPITENCIA_TRANSICIÓN', 'REPITENCIA_PRIMARIA', 'REPITENCIA_SECUNDARIA',
#        'REPITENCIA_MEDIA'],
#       dtype='object')

# %% [markdown]
# DISTRIBUCIÓN DE VARIABLES

# %%
import matplotlib.pyplot as plt

df['TASA_MATRICULACIÓN_5_16'].hist()

plt.title("Distribución de Matrícula")
plt.xlabel("Tasa de Matrícula")
plt.ylabel("Frecuencia")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(
    x=df['DESERCIÓN']
)

plt.title("Boxplot de Deserción")

plt.show()
